# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

import pandas as pd

# %%
df=pd.read_csv('filtered_babydf8sec.csv')
df
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.517556  0.468691  0.413138  0.533976  0.526760  0.488020  0.524720
# 1      0.331275  0.343102  0.340097  0.343843  0.335153  0.325096  0.319346
# 2      0.538786  0.530778  0.763115  0.554583  0.367207  0.042845  0.268275
# 3      0.501884  0.670817  0.826805  0.994096  0.932598  0.940933  0.575106
# 4      0.527527  0.581884  0.677819  0.666909  0.670024  0.649364  0.583183
# ...         ...       ...       ...       ...       ...       ...       ...
# 38766  0.488102  0.502134  0.588716  0.607865  0.718876  0.831261  0.752249
# 38767  0.539242  0.508276  0.531474  0.609622  0.610614  0.657697  0.654039
# 38768  0.448058  0.472335  0.507852  0.534972  0.740174  0.807509  0.844256
# 38769  0.489793  0.480871  0.490465  0.481622  0.491105  0.482328  0.491704
# 38770  0.554166  0.483480  0.488943  0.471808  0.519299  0.454076  0.548181
#
# ...

# %%
df_plot=df.iloc[0]
df_plot=pd.DataFrame(df_plot)
df_plot.reset_index(drop=True)
df_plot
# Out:
#              0
# 0     0.517556
# 1     0.468691
# 2     0.413138
# 3     0.533976
# 4     0.526760
# ...        ...
# 4604  0.434008
# 4605  0.269033
# 4606  0.314489
# 4607  0.529401
# 4608  0.000000
#
# [4609 rows x 1 columns]

# %%
df_plot.drop(index=['4608'],inplace=True)

# %%
col=[]
for i in range(4608):
    
    val_c=i
    col.append(val_c)

# %%
df_plot1=pd.DataFrame(col)
df_plot1=df_plot1

# %%
df_plot1.rename(columns={0:"time-steps"},inplace=True)

# %%
df_plot1
# Out:
#       time-steps
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 4603        4603
# 4604        4604
# 4605        4605
# 4606        4606
# 4607        4607
#
# [4608 rows x 1 columns]

# %%
df_plot.rename(columns={0:"EEG values"},inplace=True)

# %%
df_plot1
# Out:
#       time-steps
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 4603        4603
# 4604        4604
# 4605        4605
# 4606        4606
# 4607        4607
#
# [4608 rows x 1 columns]

# %%
df_plot
# Out:
#       EEG values
# 0       0.517556
# 1       0.468691
# 2       0.413138
# 3       0.533976
# 4       0.526760
# ...          ...
# 4604    0.434008
# 4605    0.269033
# 4606    0.314489
# 4607    0.529401
# 4608    0.000000
#
# [4609 rows x 1 columns]

# %%
df_main=pd.concat([df_plot.reset_index(drop=True),df_plot1.reset_index(drop=True)],axis=1)
df_main
# Out:
#       EEG values  time-steps
# 0       0.517556         0.0
# 1       0.468691         1.0
# 2       0.413138         2.0
# 3       0.533976         3.0
# 4       0.526760         4.0
# ...          ...         ...
# 4604    0.434008      4604.0
# 4605    0.269033      4605.0
# 4606    0.314489      4606.0
# 4607    0.529401      4607.0
# 4608    0.000000         NaN
#
# [4609 rows x 2 columns]

# %%
df_main=df_main.iloc[0:2000,:]

# %%
df_main
# Out:
#       EEG values  time-steps
# 0       0.517556         0.0
# 1       0.468691         1.0
# 2       0.413138         2.0
# 3       0.533976         3.0
# 4       0.526760         4.0
# ...          ...         ...
# 1995    0.754014      1995.0
# 1996    0.628431      1996.0
# 1997    0.574770      1997.0
# 1998    0.435806      1998.0
# 1999    0.170218      1999.0
#
# [2000 rows x 2 columns]

# %%
date = df_main["time-steps"]
value = df_main["EEG values"]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.set_xlabel('time-steps', fontsize=18,fontdict=dict(weight='bold'))
ax.set_ylabel('EEG values(in μV)', fontsize=18,fontdict=dict(weight='bold'))
ax.tick_params(axis='both', which='major', labelsize=12)
ax.plot(date, value, color="green");
plt.grid()
plt.savefig('NO_Siezure_filtered_data_8s.svg',dpi=1200)
plt.show()

# %%
np.random.seed(0)

dt = 0.01 # sampling interval
Fs = 1 / dt # sampling frequency
t = np.arange(0, 10, dt)

# generate noise:
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)
cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(4 * np.pi * t) + cnse
fig, axs = plt.subplots()
axs.set_title("Signal")
axs.plot(t, s, color='C0')
axs.set_xlabel("Time")
axs.set_ylabel("Amplitude")

plt.show()
